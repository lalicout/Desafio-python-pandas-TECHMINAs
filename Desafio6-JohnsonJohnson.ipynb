# %%
from pydataset import data

# %%
df = data('JohnsonJohnson')
df
# Out:
#        time  JohnsonJohnson
# 1   1960.00            0.71
# 2   1960.25            0.63
# 3   1960.50            0.85
# 4   1960.75            0.44
# 5   1961.00            0.61
# 6   1961.25            0.69
# 7   1961.50            0.92
# 8   1961.75            0.55
# 9   1962.00            0.72
# 10  1962.25            0.77
# 11  1962.50            0.92
# 12  1962.75            0.60
# 13  1963.00            0.83
# 14  1963.25            0.80
# 15  1963.50            1.00
# 16  1963.75            0.77
# 17  1964.00            0.92
# 18  1964.25            1.00
# 19  1964.50            1.24
# 20  1964.75            1.00
# 21  1965.00            1.16
# 22  1965.25            1.30
# 23  1965.50            1.45
# 24  1965.75            1.25
# 25  1966.00            1.26
# 26  1966.25            1.38
# 27  1966.50            1.86
# 28  1966.75            1.56
# 29  1967.00            1.53
# 30  1967.25            1.59
# 31  1967.50            1.83
# 32  1967.75            1.86
# ...

# %%
import numpy as np
import pandas as pd

# %%
arr = df['time'].to_numpy()
arr = np.trunc(arr)
arr
# Out:
# array([1960., 1960., 1960., 1960., 1961., 1961., 1961., 1961., 1962.,
#        1962., 1962., 1962., 1963., 1963., 1963., 1963., 1964., 1964.,
#        1964., 1964., 1965., 1965., 1965., 1965., 1966., 1966., 1966.,
#        1966., 1967., 1967., 1967., 1967., 1968., 1968., 1968., 1968.,
#        1969., 1969., 1969., 1969., 1970., 1970., 1970., 1970., 1971.,
#        1971., 1971., 1971., 1972., 1972., 1972., 1972., 1973., 1973.,
#        1973., 1973., 1974., 1974., 1974., 1974., 1975., 1975., 1975.,
#        1975., 1976., 1976., 1976., 1976., 1977., 1977., 1977., 1977.,
#        1978., 1978., 1978., 1978., 1979., 1979., 1979., 1979., 1980.,
#        1980., 1980., 1980.])

# %%
df2 = pd.DataFrame({'ano': arr})
df2
# Out:
#        ano
# 0   1960.0
# 1   1960.0
# 2   1960.0
# 3   1960.0
# 4   1961.0
# 5   1961.0
# 6   1961.0
# 7   1961.0
# 8   1962.0
# 9   1962.0
# 10  1962.0
# 11  1962.0
# 12  1963.0
# 13  1963.0
# 14  1963.0
# 15  1963.0
# 16  1964.0
# 17  1964.0
# 18  1964.0
# 19  1964.0
# 20  1965.0
# 21  1965.0
# 22  1965.0
# 23  1965.0
# 24  1966.0
# 25  1966.0
# 26  1966.0
# 27  1966.0
# 28  1967.0
# 29  1967.0
# 30  1967.0
# 31  1967.0
# 32  1968.0
# 33  1968.0
# 34  1968.0
# 35  1968.0
# 36  1969.0
# 37  1969.0
# 38  1969.0
# 39  1969.0
# 40  1970.0
# 41  1970.0
# 42  1970.0
# 43  1970.0
# 44  1971.0
# 45  1971.0
# 46  1971.0
# 47  1971.0
# 48  1972.0
# 49  1972.0
# 50  1972.0
# 51  1972.0
# 52  1973.0
# 53  1973.0
# 54  1973.0
# 55  1973.0
# 56  1974.0
# 57  1974.0
# 58  1974.0
# 59  1974.0
# 60  1975.0
# 61  1975.0
# 62  1975.0
# 63  1975.0
# 64  1976.0
# 65  1976.0
# 66  1976.0
# 67  1976.0
# 68  1977.0
# 69  1977.0
# 70  1977.0
# 71  1977.0
# 72  1978.0
# 73  1978.0
# 74  1978.0
# ...

# %%
df['time'] = df2['ano']
df
# Out:
#       time  JohnsonJohnson
# 1   1960.0            0.71
# 2   1960.0            0.63
# 3   1960.0            0.85
# 4   1961.0            0.44
# 5   1961.0            0.61
# 6   1961.0            0.69
# 7   1961.0            0.92
# 8   1962.0            0.55
# 9   1962.0            0.72
# 10  1962.0            0.77
# 11  1962.0            0.92
# 12  1963.0            0.60
# 13  1963.0            0.83
# 14  1963.0            0.80
# 15  1963.0            1.00
# 16  1964.0            0.77
# 17  1964.0            0.92
# 18  1964.0            1.00
# 19  1964.0            1.24
# 20  1965.0            1.00
# 21  1965.0            1.16
# 22  1965.0            1.30
# 23  1965.0            1.45
# 24  1966.0            1.25
# 25  1966.0            1.26
# 26  1966.0            1.38
# 27  1966.0            1.86
# 28  1967.0            1.56
# 29  1967.0            1.53
# 30  1967.0            1.59
# 31  1967.0            1.83
# 32  1968.0            1.86
# 33  1968.0            1.53
# ...
